# %% [markdown]
# # Machine learning project on Indian non metro jobs dataset

# %% [markdown]
# ## import the required library

# %%
# import pandas
# this library help us to convert diffrent data files(structured and sem-structured) into pandas datafreme
import pandas as pd

# import numpy
# this library help us to perform difftent numerical and statistical operation on diffrent data structure
import numpy as np

# import seaborn and matplotlib
# this both library help us to create and visualization 
import seaborn as sns
import matplotlib.pyplot as plt

# %% [markdown]
# ## load the dataset

# %%
# load the file from local
df_indian_non_metro_jobs_dataset = pd.read_csv('indian_non_metro_jobs_dataset.csv')

# %%
# show the first five observation
df_indian_non_metro_jobs_dataset.head()
# Out:
#    Job_ID        City       Industry      Job_Role  \
# 0       1      Ranchi         Retail        Retail
# 1       2  Vijayawada           Tech         AI/ML
# 2       3      Ranchi         Retail        Retail
# 3       4    Vadodara  Manufacturing         Sales
# 4       5        Agra      Education  Data Science
#
#                                 Skill_Set Experience_Level  Salary_Range  \
# 0               Customer Service, English        Mid-Level     622099.18
# 1  Python, Deep Learning, TensorFlow, NLP      Entry-Level     613072.56
# 2             MS Office, Customer Service      Entry-Level     466698.78
# 3              Negotiation, Communication      Entry-Level     352905.66
# 4         SQL, Python, Data Visualization     Senior-Level    1948630.28
#
#       Company_Name  Talent_Inflow  Talent_Outflow  Infrastructure_Score  \
# 0  Reliance Retail           1159            1583                 74.25
# ...

# %%
# show the last five observation
df_indian_non_metro_jobs_dataset.tail()
# Out:
#        Job_ID        City       Industry              Job_Role  \
# 11995   11996      Raipur        Finance  Business Development
# 11996   11997    Vadodara        Finance          Data Science
# 11997   11998  Vijayawada           Tech           Engineering
# 11998   11999  Vijayawada         Others          Data Science
# 11999   12000    Vadodara  Manufacturing          Data Science
#
#                                          Skill_Set Experience_Level  \
# 11995                  Sales, Market Analysis, CRM     Senior-Level
# 11996               Data Visualization, Statistics      Entry-Level
# 11997                                 Python, Java        Mid-Level
# 11998                              SQL, Statistics     Senior-Level
# 11999  Data Visualization, Statistics, SQL, Python     Senior-Level
#
#        Salary_Range     Company_Name  Talent_Inflow  Talent_Outflow  \
# 11995    1915750.24  Reliance Retail            538            1534
# ...

# %% [markdown]
# ## basic data overview

# %%
# check the shape of the data
df_indian_non_metro_jobs_dataset.shape
# Out:
# (12000, 18)

# %% [markdown]
# **Inference**
#  - we have 12000 observations and 18 attributes

# %%
# check the columns we have in the data
df_indian_non_metro_jobs_dataset.columns
# Out:
# Index(['Job_ID', 'City', 'Industry', 'Job_Role', 'Skill_Set',
#        'Experience_Level', 'Salary_Range', 'Company_Name', 'Talent_Inflow',
#        'Talent_Outflow', 'Infrastructure_Score', 'Smart_City_Investment',
#        'GCC_Presence', 'MSME_Growth_Rate', 'Unemployment_Rate',
#        'Education_Hubs', 'Cost_of_Living_Index', 'Job_Posting_Date'],
#       dtype='object')

# %%
# check the data info
df_indian_non_metro_jobs_dataset.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 12000 entries, 0 to 11999
# Data columns (total 18 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   Job_ID                 12000 non-null  int64
#  1   City                   12000 non-null  object
#  2   Industry               12000 non-null  object
#  3   Job_Role               12000 non-null  object
#  4   Skill_Set              12000 non-null  object
#  5   Experience_Level       12000 non-null  object
#  6   Salary_Range           12000 non-null  float64
#  7   Company_Name           12000 non-null  object
#  8   Talent_Inflow          12000 non-null  int64
#  9   Talent_Outflow         12000 non-null  int64
#  10  Infrastructure_Score   12000 non-null  float64
#  11  Smart_City_Investment  12000 non-null  float64
#  12  GCC_Presence           12000 non-null  int64
#  13  MSME_Growth_Rate       12000 non-null  float64
# ...

# %%
# example of user define function
def addition1(x,y):
    sum1=x+y
    return sum1

# %%
# call the function
addition1(10,20)
# Out:
# 30

# %% [markdown]
# **Interpretation**
#  - 1. we have 11 numerical columns and 7 catecorical columns
#  - 2. the data we have it aquires 1.6+mb storage space
#  - 3. we don't have valid null records in a data

# %%
# describe the dataset
df_indian_non_metro_jobs_dataset.describe().T
# Out:
#                          count           mean            std        min  \
# Job_ID                 12000.0    6000.500000    3464.245950       1.00
# Salary_Range           12000.0  846147.641146  607037.970547  300000.00
# Talent_Inflow          12000.0    1305.965167     783.722309       0.00
# Talent_Outflow         12000.0    1300.928083     498.169449       0.00
# Infrastructure_Score   12000.0      67.177056      11.323789      50.00
# Smart_City_Investment  12000.0    3922.670814    2180.646913    1000.66
# GCC_Presence           12000.0       0.299417       0.458022       0.00
# MSME_Growth_Rate       12000.0       7.273655       3.383855       2.00
# Unemployment_Rate      12000.0       7.483524       2.730499       2.00
# Education_Hubs         12000.0      14.781250       7.292199       5.00
# Cost_of_Living_Index   12000.0      79.984437      11.501405      60.00
#
#                               25%         50%           75%         max
# ...

# %% [markdown]
# **interpretation**
#  - from this we can easily identify the outlires , by looking at the difference between mean and 50%(median)

# %% [markdown]
# ## data preproccessing

# %% [markdown]
# ### null value handling

# %%
# cheack the count of null record present in dataframe
df_indian_non_metro_jobs_dataset.isnull().sum()
# Out:
# Job_ID                   0
# City                     0
# Industry                 0
# Job_Role                 0
# Skill_Set                0
# Experience_Level         0
# Salary_Range             0
# Company_Name             0
# Talent_Inflow            0
# Talent_Outflow           0
# Infrastructure_Score     0
# Smart_City_Investment    0
# GCC_Presence             0
# MSME_Growth_Rate         0
# Unemployment_Rate        0
# Education_Hubs           0
# Cost_of_Living_Index     0
# Job_Posting_Date         0
# dtype: int64

# %% [markdown]
# **interpritation**
#  - in the data we don't have the null records

# %% [raw]
# before performing machine learning we have to take care of few things
#  - categorical column must not contain the categories more than 15 , if the count of catagories more then 30 then drop the column
#  - we have to remove the columns who contain all unique value
#  - we have to remove the column who contain all single value

# %% [markdown]
# ## EDA(Exploratry Data Analysis)

# %%
# Step1: segrigate the data based on datatype
df_num = df_indian_non_metro_jobs_dataset.select_dtypes(include = 'number')

# %%
# make a saperate data frame for catagorical variable
df_cat = df_indian_non_metro_jobs_dataset.select_dtypes(include = 'object')

# %%
# check the columns present in categorical dataframe
df_cat.columns
# Out:
# Index(['City', 'Industry', 'Job_Role', 'Skill_Set', 'Experience_Level',
#        'Company_Name', 'Job_Posting_Date'],
#       dtype='object')

# %%
# check the catgories present in categorical columns
df_cat.City.value_counts()
# Out:
# City
# Raipur           1235
# Vijayawada       1227
# Jodhpur          1222
# Visakhapatnam    1218
# Madurai          1205
# Ranchi           1195
# Rajkot           1192
# Agra             1183
# Vadodara         1175
# Nashik           1148
# Name: count, dtype: int64

# %%
# check the columns present in categorical dataframe
df_cat.columns
# Out:
# Index(['City', 'Industry', 'Job_Role', 'Skill_Set', 'Experience_Level',
#        'Company_Name', 'Job_Posting_Date'],
#       dtype='object')

# %%
# check the catgories present in categorical columns
df_cat.Industry.value_counts()
# Out:
# Industry
# Tech             2572
# Pharma           1786
# Others           1544
# Retail           1450
# Education        1436
# Manufacturing    1134
# Healthcare       1055
# Finance          1023
# Name: count, dtype: int64

# %%
# check the columns present in categorical dataframe
df_cat.columns
# Out:
# Index(['City', 'Industry', 'Job_Role', 'Skill_Set', 'Experience_Level',
#        'Company_Name', 'Job_Posting_Date'],
#       dtype='object')

# %%
# check the catgories present in categorical columns
df_cat.Job_Role.value_counts()
# Out:
# Job_Role
# Business Development    2381
# Engineering             2259
# AI/ML                   1776
# Operations              1518
# Data Science            1500
# Others                  1018
# Sales                   1005
# Retail                   543
# Name: count, dtype: int64

# %%
# check the columns present in categorical dataframe
df_cat.columns
# Out:
# Index(['City', 'Industry', 'Job_Role', 'Skill_Set', 'Experience_Level',
#        'Company_Name', 'Job_Posting_Date'],
#       dtype='object')

# %%
# check the catgories present in categorical columns
df_cat.Skill_Set.value_counts()
# Out:
# Skill_Set
# Market Analysis, Sales, CRM                    279
# Sales, Market Analysis, CRM                    274
# CRM, Market Analysis, Sales                    265
# CRM, Sales, Market Analysis                    265
# Market Analysis, CRM, Sales                    259
#                                               ...
# Statistics, Data Visualization, Python, SQL     13
# Statistics, Python, Data Visualization, SQL     13
# SQL, Data Visualization, Statistics, Python     13
# Python, Data Visualization, Statistics          12
# SQL, Python, Data Visualization, Statistics     10
# Name: count, Length: 226, dtype: int64

# %%
# check the columns present in categorical dataframe
df_cat.columns
# Out:
# Index(['City', 'Industry', 'Job_Role', 'Skill_Set', 'Experience_Level',
#        'Company_Name', 'Job_Posting_Date'],
#       dtype='object')

# %%
# check the catgories present in categorical columns
df_cat.Experience_Level.value_counts()
# Out:
# Experience_Level
# Entry-Level     4887
# Mid-Level       4164
# Senior-Level    2346
# Internship       603
# Name: count, dtype: int64

# %%
# check the columns present in categorical dataframe
df_cat.columns
# Out:
# Index(['City', 'Industry', 'Job_Role', 'Skill_Set', 'Experience_Level',
#        'Company_Name', 'Job_Posting_Date'],
#       dtype='object')

# %%
# check the catgories present in categorical columns
df_cat.Company_Name.value_counts()
# Out:
# Company_Name
# Reliance Retail    5541
# Others             5539
# HCLTech             920
# Name: count, dtype: int64

# %%
# check the columns present in categorical dataframe
df_cat.columns
# Out:
# Index(['City', 'Industry', 'Job_Role', 'Skill_Set', 'Experience_Level',
#        'Company_Name', 'Job_Posting_Date'],
#       dtype='object')

# %%
# check the catgories present in categorical columns
df_cat.Job_Posting_Date.value_counts()
# Out:
# Job_Posting_Date
# 2025-02-12    33
# 2024-07-27    32
# 2023-07-18    30
# 2025-01-09    30
# 2023-06-23    29
#               ..
# 2024-06-09     7
# 2023-08-26     7
# 2024-10-21     7
# 2024-07-11     6
# 2024-08-08     4
# Name: count, Length: 731, dtype: int64

# %%
# Make sure the column is in datetime format
df_cat['Job_Posting_Date'] = pd.to_datetime(df_cat['Job_Posting_Date'])

# %%
# Extract basic date features
df_cat['Day'] = df_cat['Job_Posting_Date'].dt.day
df_cat['Month'] = df_cat['Job_Posting_Date'].dt.month
df_cat['Year'] = df_cat['Job_Posting_Date'].dt.year
df_cat['Weekday'] = df_cat['Job_Posting_Date'].dt.day_name()
df_cat['Quarter'] = df_cat['Job_Posting_Date'].dt.quarter

# %%
# Function to map month to season (Indian seasons)
def get_season(month):
    if month in [3, 4, 5]:
        return 'Summer'
    elif month in [6, 7, 8, 9]:
        return 'Monsoon'
    else:
        return 'Winter'

# Apply season mapping
df_cat['Season'] = df_cat['Month'].apply(get_season)

# %%
# check the categorical dataframe
df_cat.head()
# Out:
#          City       Industry      Job_Role  \
# 0      Ranchi         Retail        Retail
# 1  Vijayawada           Tech         AI/ML
# 2      Ranchi         Retail        Retail
# 3    Vadodara  Manufacturing         Sales
# 4        Agra      Education  Data Science
#
#                                 Skill_Set Experience_Level     Company_Name  \
# 0               Customer Service, English        Mid-Level  Reliance Retail
# 1  Python, Deep Learning, TensorFlow, NLP      Entry-Level          HCLTech
# 2             MS Office, Customer Service      Entry-Level  Reliance Retail
# 3              Negotiation, Communication      Entry-Level  Reliance Retail
# 4         SQL, Python, Data Visualization     Senior-Level  Reliance Retail
#
#   Job_Posting_Date  Day  Month  Year    Weekday  Quarter   Season
# 0       2023-10-15   15     10  2023     Sunday        4   Winter
# 1       2023-03-31   31      3  2023     Friday        1   Summer
# ...

# %%
import pandas as pd

# Make sure the column is in datetime format
df_indian_non_metro_jobs_dataset['Job_Posting_Date'] = pd.to_datetime(df_indian_non_metro_jobs_dataset['Job_Posting_Date'])

# Extract basic date features
df_indian_non_metro_jobs_dataset['Day'] = df_indian_non_metro_jobs_dataset['Job_Posting_Date'].dt.day
df_indian_non_metro_jobs_dataset['Month'] = df_indian_non_metro_jobs_dataset['Job_Posting_Date'].dt.month
df_indian_non_metro_jobs_dataset['Year'] = df_indian_non_metro_jobs_dataset['Job_Posting_Date'].dt.year
df_indian_non_metro_jobs_dataset['Weekday'] = df_indian_non_metro_jobs_dataset['Job_Posting_Date'].dt.day_name()
df_indian_non_metro_jobs_dataset['Quarter'] = df_indian_non_metro_jobs_dataset['Job_Posting_Date'].dt.quarter

# Function to map month to season (Indian seasons)
def get_season(month):
    if month in [3, 4, 5]:
        return 'Summer'
    elif month in [6, 7, 8, 9]:
        return 'Monsoon'
    else:
        return 'Winter'

# Apply season mapping
df_indian_non_metro_jobs_dataset['Season'] = df_indian_non_metro_jobs_dataset['Month'].apply(get_season)

# Display the first few rows to verify
df_indian_non_metro_jobs_dataset.head()
# Out:
#    Job_ID        City       Industry      Job_Role  \
# 0       1      Ranchi         Retail        Retail
# 1       2  Vijayawada           Tech         AI/ML
# 2       3      Ranchi         Retail        Retail
# 3       4    Vadodara  Manufacturing         Sales
# 4       5        Agra      Education  Data Science
#
#                                 Skill_Set Experience_Level  Salary_Range  \
# 0               Customer Service, English        Mid-Level     622099.18
# 1  Python, Deep Learning, TensorFlow, NLP      Entry-Level     613072.56
# 2             MS Office, Customer Service      Entry-Level     466698.78
# 3              Negotiation, Communication      Entry-Level     352905.66
# 4         SQL, Python, Data Visualization     Senior-Level    1948630.28
#
#       Company_Name  Talent_Inflow  Talent_Outflow  ...  Unemployment_Rate  \
# 0  Reliance Retail           1159            1583  ...               9.28
# ...

# %% [markdown]
# ## prepare the data for machine learning

# %%
# Step1: segrigate the data based on datatype
df_num = df_indian_non_metro_jobs_dataset.select_dtypes(include = 'number')

# make a saperate data frame for catagorical variable
df_cat = df_indian_non_metro_jobs_dataset.select_dtypes(include = 'object')

# %% [markdown]
# ### perform encoding

# %%
# perform encoding(one hot encoding)
df_encoded = pd.get_dummies(df_cat)

# %%
# check the encoded data
df_encoded.head()
# Out:
#    City_Agra  City_Jodhpur  City_Madurai  City_Nashik  City_Raipur  \
# 0      False         False         False        False        False
# 1      False         False         False        False        False
# 2      False         False         False        False        False
# 3      False         False         False        False        False
# 4       True         False         False        False        False
#
#    City_Rajkot  City_Ranchi  City_Vadodara  City_Vijayawada  \
# 0        False         True          False            False
# 1        False        False          False             True
# 2        False         True          False            False
# 3        False        False           True            False
# 4        False        False          False            False
#
#    City_Visakhapatnam  ...  Weekday_Friday  Weekday_Monday  Weekday_Saturday  \
# 0               False  ...           False           False             False
# ...

# %%
# Perform encoding(One Hot Encoding) 
df_encoded = pd.get_dummies(df_cat)

# %%
# Check the encoded data 
df_encoded.head()
# Out:
#    City_Agra  City_Jodhpur  City_Madurai  City_Nashik  City_Raipur  \
# 0      False         False         False        False        False
# 1      False         False         False        False        False
# 2      False         False         False        False        False
# 3      False         False         False        False        False
# 4       True         False         False        False        False
#
#    City_Rajkot  City_Ranchi  City_Vadodara  City_Vijayawada  \
# 0        False         True          False            False
# 1        False        False          False             True
# 2        False         True          False            False
# 3        False        False           True            False
# 4        False        False          False            False
#
#    City_Visakhapatnam  ...  Weekday_Friday  Weekday_Monday  Weekday_Saturday  \
# 0               False  ...           False           False             False
# ...

# %%
# Chech the dataframe to decide a target variable
df_indian_non_metro_jobs_dataset.head()
# Out:
#    Job_ID        City       Industry      Job_Role  \
# 0       1      Ranchi         Retail        Retail
# 1       2  Vijayawada           Tech         AI/ML
# 2       3      Ranchi         Retail        Retail
# 3       4    Vadodara  Manufacturing         Sales
# 4       5        Agra      Education  Data Science
#
#                                 Skill_Set Experience_Level  Salary_Range  \
# 0               Customer Service, English        Mid-Level     622099.18
# 1  Python, Deep Learning, TensorFlow, NLP      Entry-Level     613072.56
# 2             MS Office, Customer Service      Entry-Level     466698.78
# 3              Negotiation, Communication      Entry-Level     352905.66
# 4         SQL, Python, Data Visualization     Senior-Level    1948630.28
#
#       Company_Name  Talent_Inflow  Talent_Outflow  ...  Unemployment_Rate  \
# 0  Reliance Retail           1159            1583  ...               9.28
# ...

# %%
# After discussion we decided to take salary as our target variable (Depentdent variable)
target = df_indian_non_metro_jobs_dataset.Salary_Range

# After storing this variable into target we have to remove it from the main dataframe (Indepentdent variable)
df_indian_non_metro_jobs_dataset = df_indian_non_metro_jobs_dataset.drop('Salary_Range', axis = 1 )

# %%
#Step 1: Sedregate the data based on data type
df_num = df_indian_non_metro_jobs_dataset.select_dtypes(include = 'number')

#Step 2: Make the seperate dataframe for catgorical columns 
df_cat = df_indian_non_metro_jobs_dataset.select_dtypes(include = 'object')

# %% [markdown]
# ### Scale the numerical variables

# %% [raw]
# Formally any algorithm gives the improtance based on the number of digits present in the observation and these proccess is not based on the fearture improtance for predictions , to avoid this basieness we have noramlization or scaling on the numerical data

# %%
# Import standart scaler-sub package of performing the scaling
from sklearn.preprocessing import StandardScaler

# %%
# Inciate the Standard Scaler 
ss = StandardScaler()

# %%
# Transfor the numerical variables 
scale = ss.fit_transform(df_num)


# Space check tranform data
scale
# Out:
# array([[-1.73190648, -0.1875298 ,  0.5662404 , ...,  1.01376383,
#         -1.0585089 ,  1.3430051 ],
#        [-1.7316178 ,  3.15563032, -1.3709322 , ..., -1.00760347,
#         -1.0585089 , -1.33600989],
#        [-1.73132913,  0.37008889,  0.53010661, ...,  1.59129735,
#          0.5442806 ,  1.3430051 ],
#        ...,
#        [ 1.73132913,  1.1203859 , -2.61152564, ...,  0.43623032,
#         -1.0585089 ,  0.4500001 ],
#        [ 1.7316178 ,  1.30668413, -1.63390589, ..., -1.29637023,
#          2.1470701 , -1.33600989],
#        [ 1.73190648, -0.18114973, -0.00788536, ..., -1.58513699,
#          0.5442806 , -1.33600989]])

# %%
# Create a new dataframe for scaled data
df_scale = pd.DataFrame(scale,columns=df_num.columns)

# %%
# Check the scaled dataframe 
df_scale.head()
# Out:
#      Job_ID  Talent_Inflow  Talent_Outflow  Infrastructure_Score  \
# 0 -1.731906      -0.187530        0.566240              0.624635
# 1 -1.731618       3.155630       -1.370932              1.495405
# 2 -1.731329       0.370089        0.530107             -1.084228
# 3 -1.731040       0.015357       -0.148406              0.528374
# 4 -1.730752      -0.174770        2.429138             -1.278517
#
#    Smart_City_Investment  GCC_Presence  MSME_Growth_Rate  Unemployment_Rate  \
# 0               2.402845     -0.653745         -0.317301           0.657957
# 1               0.431018      1.529649         -1.328024          -1.524885
# 2               0.597769     -0.653745         -0.716271          -0.547001
# 3               0.218971     -0.653745         -0.680807           0.606682
# 4              -0.763682     -0.653745         -0.970429          -0.323590
#
#    Education_Hubs  Cost_of_Living_Index       Day     Month      Year  \
# ...

# %%
# Do the concatenation 
X = pd.concat([df_encoded,df_scale] , axis=1)

#Check the concatenated data
X.head()
# Out:
#    City_Agra  City_Jodhpur  City_Madurai  City_Nashik  City_Raipur  \
# 0      False         False         False        False        False
# 1      False         False         False        False        False
# 2      False         False         False        False        False
# 3      False         False         False        False        False
# 4       True         False         False        False        False
#
#    City_Rajkot  City_Ranchi  City_Vadodara  City_Vijayawada  \
# 0        False         True          False            False
# 1        False        False          False             True
# 2        False         True          False            False
# 3        False        False           True            False
# 4        False        False          False            False
#
#    City_Visakhapatnam  ...  Smart_City_Investment  GCC_Presence  \
# 0               False  ...               2.402845     -0.653745
# 1               False  ...               0.431018      1.529649
# ...

# %%
# Import the train test split
from sklearn.model_selection import train_test_split

# %%
# Verify shapes
print("Shape of X:", X.shape)
print("Shape of target:", target.shape)
# Out:
# Shape of X: (12000, 283)
# Shape of target: (12000,)

# %%
# Create xtrain, xtest, ytrain, ytest
X_train,X_test,y_train,y_test = train_test_split(X,target,test_size=0.20,random_state=42) # random_state use for static learning (same answers in output)

# %%
# Authentic check training set
print(X_train.shape)

print(y_train.shape)
# Out:
# (9600, 283)
# (9600,)

# %%
# Authentic check testing set
print(X_test.shape)

print(y_test.shape)
# Out:
# (2400, 283)
# (2400,)

# %% [raw]
# For finding the base algorithm we are going to follow hit and trial method, that means based on problem type (Reggression problem or Classification problem) we have to try all supported algorithms and based evalutation matrix we have to find our base model
#
# For reggession models/problems the evaluation matrix is MSE, RMSE, Rsquere, adjustedRsquere
#
# For classification models/problems the evaliation model is f1 score, accurise ,confusion matrix, pression and recall

# %% [markdown]
# ## Find the base Machine Learning Algorithm

# %% [markdown]
# ### Linear Regression

# %%
# Import linear regression algorithm and evalutaion matrix 
from sklearn.linear_model import LinearRegression 

# Here we are using MSE as evaluation matrix
from sklearn.metrics import mean_squared_error

# %%
# Create a Linear Regression Model
model = LinearRegression()

# %%
# Fit the model to training data
model.fit(X_train,y_train)
# Out:
# LinearRegression()

# %%
#Predict the testing data 
predicitions = model.predict(X_test)

# %%
# Caluculate the mean squared error
mse = mean_squared_error(y_test,predicitions)
print("Mean squared Error",mse)
# Out:
# Mean squared Error 55905762722.74794

# %% [markdown]
# ### Rigid Model

# %%
from sklearn.model_selection import train_test_split
from sklearn.linear_model import Ridge
from sklearn.metrics import mean_squared_error

# Assuming X_train, X_test, y_train, y_test are already defined from train_test_split

# Create a Ridge regression model
ridge_model = Ridge(alpha=1.0)  # alpha is the regularization strength

# Fit the model to the training data
ridge_model.fit(X_train, y_train)

# Predict on the testing data
predictions = ridge_model.predict(X_test)

# Calculate mean squared error
mse = mean_squared_error(y_test, predictions)
print("Mean Squared Error:", mse)
# Out:
# Mean Squared Error: 55772979904.81673

# %% [markdown]
# ### Lasso Model

# %%
from sklearn.model_selection import train_test_split
from sklearn.linear_model import Lasso
from sklearn.metrics import mean_squared_error

# Assuming X_train, X_test, y_train, y_test are already defined from train_test_split

# Create a Lasso regression model
lasso_model = Lasso(alpha=1.0)  # alpha is the regularization strength

# Fit the model to the training data
lasso_model.fit(X_train, y_train)

# Predict on the testing data
predictions = lasso_model.predict(X_test)

# Calculate mean squared error
mse = mean_squared_error(y_test, predictions)
print("Mean Squared Error:", mse)
# Out:
# Mean Squared Error: 55886756804.02718
# C:\ProgramData\anaconda3\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:697: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.517e+14, tolerance: 3.540e+11
#   model = cd_fast.enet_coordinate_descent(

# %% [markdown]
# ### Decision tree model

# %%
from sklearn.model_selection import train_test_split
from sklearn.tree import DecisionTreeRegressor
from sklearn.metrics import mean_squared_error

# Assuming X_train, X_test, y_train, y_test are already defined from train_test_split

# Create a Decision Tree regression model
tree_model = DecisionTreeRegressor()

# Fit the model to the training data
tree_model.fit(X_train, y_train)

# Predict on the testing data
predictions = tree_model.predict(X_test)

# Calculate mean squared error
mse = mean_squared_error(y_test, predictions)
print("Mean Squared Error:", mse)
# Out:
# Mean Squared Error: 76886257485.14395

# %% [markdown]
# ### Random forest regressor

# %%
from sklearn.model_selection import train_test_split
from sklearn.ensemble import RandomForestRegressor
from sklearn.metrics import mean_squared_error

# Assuming X_train, X_test, y_train, y_test are already defined from train_test_split

# Create a Random Forest regression model
forest_model = RandomForestRegressor(n_estimators=100, random_state=42)

# Fit the model to the training data
forest_model.fit(X_train, y_train)

# Predict on the testing data
predictions = forest_model.predict(X_test)

# Calculate mean squared error
mse = mean_squared_error(y_test, predictions)
print("Mean Squared Error:", mse)
# Out:
# Mean Squared Error: 43069289152.56289

# %% [markdown]
# ### SVR

# %%
from sklearn.model_selection import GridSearchCV
from sklearn.ensemble import RandomForestRegressor
from sklearn.preprocessing import LabelEncoder
from sklearn.metrics import r2_score

# Define the Random Forest model
rf = RandomForestRegressor(random_state=42)

# Define the hyperparameter grid
param_grid = {
    'n_estimators': [100, 200, 300],
    'max_depth': [10, 20, 30, None],
    'min_samples_split': [2, 5, 10],
    'min_samples_leaf': [1, 2, 4],
    'max_features': ['auto', 'sqrt', 'log2']
}

# Perform GridSearchCV for hyperparameter tuning
grid_search = GridSearchCV(estimator=rf, param_grid=param_grid, 
                           cv=5, scoring='neg_mean_squared_error', 
                           n_jobs=-1, verbose=2)

# Fit the model
grid_search.fit(X_train, y_train)

# Get the best parameters and model
best_params = grid_search.best_params_
best_rf = grid_search.best_estimator_

# Predict on the test set
y_pred = best_rf.predict(X_test)

# Evaluate the model
mse = mean_squared_error(y_test, y_pred)
r2 = r2_score(y_test, y_pred)

print("Best Hyperparameters:", best_params)
print("Test MSE:", mse)
print("Test R²:", r2)

# Feature importance
feature_importance = pd.DataFrame({
    'Feature': X.columns,
    'Importance': best_rf.feature_importances_
}).sort_values(by='Importance', ascending=False)

print("\nFeature Importance:")
print(feature_importance)
# Out:
# Fitting 5 folds for each of 324 candidates, totalling 1620 fits
# C:\ProgramData\anaconda3\Lib\site-packages\sklearn\model_selection\_validation.py:540: FitFailedWarning:
# 540 fits failed out of a total of 1620.
# The score on these train-test partitions for these parameters will be set to nan.
# If these failures are not expected, you can try to debug them by setting error_score='raise'.
#
# Below are more details about the failures:
# --------------------------------------------------------------------------------
# 262 fits failed with the following error:
# Traceback (most recent call last):
#   File "C:\ProgramData\anaconda3\Lib\site-packages\sklearn\model_selection\_validation.py", line 888, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "C:\ProgramData\anaconda3\Lib\site-packages\sklearn\base.py", line 1466, in wrapper
#     estimator._validate_params()
# ...

# %%
from sklearn.model_selection import KFold
# Set up k-fold cross-validation (e.g., k=5)
k = 5
kf = KFold(n_splits=k, shuffle=True, random_state=42)

# Lists to store metrics for each fold
mse_scores = []
r2_scores = []

# Perform k-fold cross-validation
for fold, (train_index, test_index) in enumerate(kf.split(X), 1):
    # Split data into training and test sets for this fold
    X_train, X_test = X_train.iloc[train_index], X_train.iloc[test_index]
    y_train, y_test = y_train.iloc[train_index], y_train.iloc[test_index]

    # Train the model
    rf.fit(X_train, y_train)

    # Predict on the test set
    y_pred = rf.predict(X_test)

    # Calculate metrics
    mse = mean_squared_error(y_test, y_pred)
    r2 = r2_score(y_test, y_pred)

    # Store metrics
    mse_scores.append(mse)
    r2_scores.append(r2)

    print(f"Fold {fold} - MSE: {mse:.2f}, R²: {r2:.4f}")

# Calculate mean and standard deviation of metrics
mean_mse = np.mean(mse_scores)
std_mse = np.std(mse_scores)
mean_r2 = np.mean(r2_scores)
std_r2 = np.std(r2_scores)

print("\nK-Fold Cross-Validation Results (k={})".format(k))
print(f"Mean MSE: {mean_mse:.2f} (± {std_mse:.2f})")
print(f"Mean R²: {mean_r2:.4f} (± {std_r2:.4f})")

# Train the model on the full dataset to get feature importance
rf.fit(X, y)
feature_importance = pd.DataFrame({
    'Feature': X.columns,
    'Importance': rf.feature_importances_
}).sort_values(by='Importance', ascending=False)

print("\nFeature Importance:")
print(feature_importance)
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# File C:\ProgramData\anaconda3\Lib\site-packages\pandas\core\indexing.py:1714, in _iLocIndexer._get_list_axis(self, key, axis)
#    1713 try:
# -> 1714     return self.obj._take_with_is_copy(key, axis=axis)
#    1715 except IndexError as err:
#    1716     # re-raise with different error message, e.g. test_getitem_ndarray_3d
#
# File C:\ProgramData\anaconda3\Lib\site-packages\pandas\core\generic.py:4153, in NDFrame._take_with_is_copy(self, indices, axis)
#    4144 """
#    4145 Internal version of the `take` method that sets the `_is_copy`
#    4146 attribute to keep track of the parent dataframe (using in indexing
#    (...)
#    4151 See the docstring of `take` for full explanation of the parameters.
#    4152 """
# -> 4153 result = self.take(indices=indices, axis=axis)
# ...

# %% [markdown]
# ### Feature selaction for base algorithem

# %%
from sklearn.ensemble import RandomForestRegressor
from sklearn.feature_selection import RFE
from sklearn.metrics import mean_squared_error, r2_score

# Step 1: Initialize the model
rf_model = RandomForestRegressor(random_state=42)

# Step 2: Set up RFE
# You can specify the number of features to select (e.g., 5 or len(X_train.columns)//2)
n_features_to_select = 100  # Change as needed
rfe = RFE(estimator=rf_model, n_features_to_select=n_features_to_select)

# Step 3: Fit RFE on training data
rfe.fit(X_train, y_train)

# Step 4: Get selected features
selected_features = X_train.columns[rfe.support_]
print("Selected Features:", list(selected_features))

# Step 5: Train model on selected features
rf_model.fit(X_train[selected_features], y_train)

# Step 6: Predict on test set using selected features
y_pred = rf_model.predict(X_test[selected_features])

# Step 7: Evaluate
mse = mean_squared_error(y_test, y_pred)
r2 = r2_score(y_test, y_pred)

print("Mean Squared Error:", mse)
print("R^2 Score:", r2)

# %%
import joblib

#Assuming 'rf' is your trained model
joblib.dump(rf,'model.pkl')

# %%
import streamlit as st
import joblib
import numpy as np

# Load the trained model
model = joblib.load('model.pkl')

st.title("Random Forest Regression Predictor")

# Example: Assume you need 10 features as input
inputs = []
for i in range(100):
    val = st.number_input(f"Feature {i+1}", value=0.0)
    inputs.append(val)

if st.button("Predict"):
    prediction = model.predict([inputs])
    st.success(f"Predicted Output: {prediction[0]}")
